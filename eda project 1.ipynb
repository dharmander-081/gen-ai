# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.head()

# %%
df.tail()

# %%
df.head(12)

# %%
df.info()

# %%
df.describe()

# %%
df.isna().sum()

# %%
df.dropna(inplace=True)
df.isna().sum()

# %%
df.duplicated().value_counts()

# %%
dfa=df.drop_duplicates(subset=None, keep='first', inplace=False)
dfa

# %%
dfa.columns = ['order_ID', 'product', 'quantity_ordered', 'price_each', 'order_date', 'purchase_address']
dfa.head()

# %%
dfa

# %%
dfa['date'] = dfa['order_date'].str[:8]
dfa

# %%
df.dtypes

# %%
nan_df = df[df.isna().any(axis=1)]
nan_df.head()

# %%
dfa['month'] = dfa['order_date'].str[:2]
dfa

# %%
dfa.month.value_counts()

# %%
dfa = dfa[dfa['month'].str[:2] != 'or']
dfa.head()

# %%
dfa.info()

# %%
df.info()

# %%
dfa['month'] = dfa['month'].astype('int64')
dfa['order_date'] = pd.to_datetime(dfa['order_date'])
dfa['date'] = pd.to_datetime(dfa['date'])
dfa.info()

# %%
df.info()

# %%
dfa['quantity_ordered'] = dfa['quantity_ordered'].astype('int32')
dfa['price_each'] = dfa['price_each'].astype('float64')
dfa.info()

# %%
# Remove rows where 'quantity_ordered' is not numeric
dfa = dfa[dfa['quantity_ordered'].str.isnumeric()]

# Now safely convert
dfa['quantity_ordered'] = dfa['quantity_ordered'].astype('int32')
dfa['price_each'] = dfa['price_each'].astype('float64')

dfa.info()

# %%
dfa['quantity_ordered'] = dfa['quantity_ordered'].astype('int32')
dfa['price_each'] = dfa['price_each'].astype('float64')
dfa.info()

# %%
dfa['sales'] = dfa['quantity_ordered'] * dfa['price_each']
dfa

# %%
monthly_sales = dfa.groupby('month').sales.sum()
monthly_sales

# %%
city_sales=dfa.city.value_counts()
city_sales

# %%
city_sales=dfa.city.value_counts()
city_sales

# %%
print(dfa.columns)

# %%
print(dfa['city'].head())   # Replace 'city' with actual column name if different

# %%
print(dfa.columns)

# %%
print(dfa['city'].head())   # Replace 'city' with actual column name if different

# %%
city_sales = dfa['city'].value_counts(dropna=True)
print(city_sales)

# %%
print(dfa.columns)

# %%
city_sales = dfa['City'].value_counts()  # replace 'City' with the exact name you saw
print(city_sales)

# %%
print(dfa.columns.tolist())

# %%
city_sales = dfa['<exact_column_name>'].value_counts()
print(city_sales)

# %%
dfa['<exact_column_name>']

# %%
print(dfa.columns.tolist())

# %%
city_sales = dfa['City '].value_counts()  
print(city_sales)

# %%
print(dfa.columns.tolist())

# %%
city_sales = dfa['Customer City'].value_counts()
print(city_sales)

# %%
print(dfa.columns.tolist())

# %%
city_sales = dfa['City '].value_counts()
print(city_sales)

# %%
print(dfa.columns.tolist())

# %%
city_sales = dfa['city_name'].value_counts()
print(city_sales)

# %%
df.tail(10)

# %%
# Show columns clearly with their repr, so spaces or hidden characters are visible
for col in dfa.columns:
    print(repr(col))

# %%
city_sales = dfa['<exact_column_name>'].value_counts()
print(city_sales)

# %%
# This will print all column names exactly as they exist
for col in dfa.columns:
    print(repr(col))

# %%
city_sales = dfa['city'].value_counts()
print(city_sales)

# %%
# Show all column names clearly, including spaces or hidden characters
for col in dfa.columns:
    print(repr(col))

# %%
city_sales = dfa['Customer City'].value_counts()
print(city_sales)

# %%
import pandas as pd

dfa = pd.read_csv(r"C:\Users\dhruv thakur\OneDrive\Documents\gen ai\Sales_April_2019.csv")

# %%
print(dfa.columns.tolist())

# %%
city_sales = dfa['Customer City'].value_counts()
print(city_sales)

# %%
nan_df = df[df.isna().any(axis=1)]
nan_df.head()

# %%
df.dropna(inplace=True)
df.isna().sum()

# %%
dfa=df.drop_duplicates(subset=None, keep='first',inplace=False)
dfa

# %%
dfa.columns = ['Order_ID','Product','Quantity_Ordered','Price_Each','Order_Date','Purchase_Address']
dfa.head()

# %%
dfa['Date'] = dfa['Order_Date'].str[:8]
dfa

# %%
city_sales=dfa.city.value_counts()
city_sales

# %%
print(dfa.columns.tolist())

# %%
city_sales = dfa['City Name'].value_counts()
print(city_sales)
